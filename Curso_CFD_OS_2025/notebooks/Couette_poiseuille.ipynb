# %% [markdown]
# # Flujos de Couette y de Poiseuille

# %%
# %matplotlib inline

# %%
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ## Parámetros

# %%
L  = 1.0           # longitud del sistema 1D
nx = 42            # nodos espaciales
dx = L / (nx-2)    # sí, quitamos dos nodos ...
x = np.linspace( 0 , L , num=nx )

T= 0.01            # tiempo total
nt = 500            # pasos temporales
dt = T / nt

c = 1              # caída de presión
nu = 1             # coeficiente de viscosidad dinámica

# %% [markdown]
# Número de Reynolds

# %%
##   Re  ??? Co =  * dt / nu

# %% [markdown]
# ### Condiciones iniciales

# %%
u0 = 1 * np.ones(nx)                    # todo uno
x1 = L/4 ; n1 = int(x1 / dx)
x2 = L/2 ; n2 = int(x2 / dx)
u0[ n1 : n2 ] = 2

# %%
plt.plot( x , u0 )

# %% [markdown]
# ### Un paso en el tiempo

# %% [markdown]
# Recordemos que queremos implementar $u_i^{n+1} = u_i^n - \mathrm{Co}(u_{i+1}^n-u_{i-1}^n)/2$

# %%
u = u0.copy()

# %%
_valor_izdo = u[0]

# %%
un = u.copy()         # distribución actual

i = 1
u[i] = un[i] - (Co / 2.0) * (un[i+1] - _valor_izdo )

for i in range( 2 , nx - 2 ):    # Ahora queda claro por qué hemos quitado los extremos !!
   u[i] = un[i] - (Co / 2.0) * (un[i+1] - un[i-1])

# %%
plt.plot(x,u)

# %% [markdown]
# ### Tiempo completo

# %%
u = u0.copy()

# %%
for n in range(nt):
    un = u.copy()
    for i in range( 1 , nx - 1 ): 
        u[i] = un[i] - (Co / 2.0) * (un[i+1] - un[i-1])

# %%
plt.plot(x , u , x , u0 , 'r')
# Out:
# [<matplotlib.lines.Line2D at 0x7f3ef53ea990>,
#  <matplotlib.lines.Line2D at 0x7f3ef53eaad0>]

# %% [markdown]
# ### Formulaciones alternativas

# %% [markdown]
# ¿Qué pasa si probamos el algoritmo "peor"?  $u_i^{n+1} = u_i^n - \mathrm{Co} (u_{i}^n-u_{i-1}^n)$

# %%
u = u0.copy()

# %%
for n in range(nt):
    un = u.copy()
    for i in range( 1 , nx ): 
        u[i] = un[i] - Co  * (un[i] - un[i-1])

# %%
plt.plot(x , u , x , u0 , 'r')
# Out:
# [<matplotlib.lines.Line2D at 0x7f3ef5471810>,
#  <matplotlib.lines.Line2D at 0x7f3ef5471950>]

# %% [markdown]
# ### Reflexiones

# %% [markdown]
# * ¿Qué hemos hecho en los bordes? (condiciones de contorno)
# * ¿Por qué los algoritmos difieren tantísimo?
# * ¿Cuántos parámetros hay realmente? (Pista: 1)
