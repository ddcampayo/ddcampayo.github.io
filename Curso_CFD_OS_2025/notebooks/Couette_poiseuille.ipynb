# %% [markdown]
# # Flujos de Couette y de Poiseuille

# %%
# %matplotlib inline

# %%
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ## Parámetros

# %%
L  = 1.0           # longitud del sistema 1D
nx = 42            # nodos espaciales
dx = L / (nx+1)    
x = np.linspace( 0 , L - dx , num=nx )

T= 0.1            # tiempo total
nt = 500            # pasos temporales
dt = T / nt

nu = 1             # coeficiente de viscosidad dinámica

# %% [markdown]
# Número de Reynolds

# %%
##   Re  ??? Co =  * dt / nu

# %%
CoD = nu*dt/dx**2
CoD
# Out:
# 0.3698000000000001

# %% [markdown]
# # Couette

# %% [markdown]
# ### Condiciones iniciales

# %%
u0 = np.zeros(nx)                    # todo cero
u0[ 0 ] = 1

# %%
plt.plot( x , u0 )

# %% [markdown]
# ### Un paso en el tiempo

# %%
u = u0.copy()

# %%
un = u.copy()         # distribución actual

i = 0
u[i] = un[i] + (CoD / 2.0) * (un[i+1] + 1 - 2*u[0] )

for i in range( 1 , nx - 1 ):
   u[i] = un[i] + (CoD / 2.0) * (un[i+1] + un[i-1] - 2 * un[i] )

i = nx - 1

u[i] = un[i] + (CoD / 2.0) * ( 0 + un[i-1] - 2 * un[i] )

# %%
plt.plot(x,u)

# %% [markdown]
# ### Tiempo completo

# %%
u = u0.copy()

# %%
for n in range(nt):
    un = u.copy()

    i = 0
    u[i] = un[i] + (CoD / 2.0) * (un[i+1] + 1 - 2* u[0] )

    for i in range( 1 , nx - 1 ):
       u[i] = un[i] + (CoD / 2.0) * (un[i+1] + un[i-1] - 2 * un[i] )

    i = nx - 1

    u[i] = un[i] + (CoD / 2.0) * ( 0 + un[i-1] - 2 * un[i] )

# %%
plt.plot(x , u , x , u0 , 'r', x , 1-x)
# Out:
# [<matplotlib.lines.Line2D at 0x7f6e852c5090>,
#  <matplotlib.lines.Line2D at 0x7f6e852c51d0>,
#  <matplotlib.lines.Line2D at 0x7f6e852c5310>]

# %% [markdown]
# # Poiseuille

# %%
c = 1              # caída de presión
nu = 1             # coeficiente de viscosidad dinámica

# %%
u0 = np.zeros( nx )

# %% [markdown]
# ### Un paso en el tiempo

# %%
u = u0.copy()

# %%
un = u.copy()         # distribución actual

i = 0
u[i] = un[i] +  c * dt + (CoD / 2.0) * (un[i+1] + 0 - 2*u[0] )

for i in range( 1 , nx - 1 ):
   u[i] = un[i] +  c * dt + (CoD / 2.0) * (un[i+1] + un[i-1] - 2 * un[i] )

i = nx - 1

u[i] = un[i] +  c * dt +(CoD / 2.0) * ( 0 + un[i-1] - 2 * un[i] )

# %%
plt.plot(x,u)

# %% [markdown]
# ### Tiempo completo

# %%
u = u0.copy()

# %%
for n in range(nt):
    un = u.copy()

    i = 0
    u[i] = un[i] + c * dt + (CoD / 2.0) * (un[i+1] + 0 - 2* u[0] )

    for i in range( 1 , nx - 1 ):
       u[i] = un[i] + c * dt + (CoD / 2.0) * (un[i+1] + un[i-1] - 2 * un[i] )

    i = nx - 1

    u[i] = un[i] + c * dt + (CoD / 2.0) * ( 0 + un[i-1] - 2 * un[i] )

# %%
plt.plot(x , u , x , u0 , 'r', x , x*(1-x)/nu )
# Out:
# [<matplotlib.lines.Line2D at 0x7f6e84cb6850>,
#  <matplotlib.lines.Line2D at 0x7f6e84cb6990>,
#  <matplotlib.lines.Line2D at 0x7f6e84cb6ad0>]
