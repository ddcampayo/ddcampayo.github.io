# %% [markdown]
# # Convección en una dimensión

# %%
# %matplotlib inline

# %%
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ## Parámetros

# %%
L  = 1.0           # longitud del sistema 1D
nx = 42            # nodos espaciales
dx = L / (nx-2)    # sí, quitamos dos nodos ...
x = np.linspace( 0 , L , num=nx )

T= 0.05            # tiempo total
nt = 100            # pasos temporales
dt = T / nt

c = 1              # velocidad de la onda

# %% [markdown]
# ### ¡Número de Courant !

# %%
Co = c * dt / dx
Co
# Out:
# 0.02

# %% [markdown]
# ### Condiciones iniciales

# %%
f0 = 1 * np.ones(nx)                    # todo uno
x1 = L/4 ; n1 = int(x1 / dx)
x2 = L/2 ; n2 = int(x2 / dx)
f0[ n1 : n2 ] = 2

# %%
plt.plot( x , f0 )

# %% [markdown]
# ### Un paso en el tiempo

# %% [markdown]
# Recordemos que queremos implementar $f_i^{n+1} = f_i^n - \mathrm{Co}(f_{i+1}^n-f_{i-1}^n)/2$

# %%
f = f0.copy()

# %%
_valor_izdo = f[0]

# %%
fn = f.copy()         # distribución actual

i = 1
f[i] = fn[i] - (Co / 2.0) * (fn[i+1] - _valor_izdo )

for i in range( 2 , nx - 2 ):    # Ahora queda claro por qué hemos quitado los extremos !!
   f[i] = fn[i] - (Co / 2.0) * (fn[i+1] - fn[i-1])

# %%
plt.plot(x,f , x, f0)
# Out:
# [<matplotlib.lines.Line2D at 0x7f07fe86cad0>,
#  <matplotlib.lines.Line2D at 0x7f07fe86cc20>]

# %% [markdown]
# ### Tiempo completo

# %%
f = f0.copy()

# %%
for n in range(nt):
    fn = f.copy()
    for i in range( 1 , nx - 1 ): 
        f[i] = fn[i] - (Co / 2.0) * (fn[i+1] - fn[i-1])

# %%
plt.plot(x , f ,  x  , f0 ,  x + c * T , f0 , 'r')
# Out:
# [<matplotlib.lines.Line2D at 0x7f07fe7263c0>,
#  <matplotlib.lines.Line2D at 0x7f07fe726510>,
#  <matplotlib.lines.Line2D at 0x7f07fe726660>]

# %% [markdown]
# ### Formulaciones alternativas

# %% [markdown]
# ¿Qué pasa si probamos el algoritmo "peor"?    $f_i^{n+1} = f_i^n - \mathrm{Co} (f_{i}^n-f_{i-1}^n)$

# %%
f = f0.copy()

# %%
for n in range(nt):
    fn = f.copy()
    for i in range( 1 , nx ): 
        f[i] = fn[i] - Co  * (fn[i] - fn[i-1])

# %%
plt.plot(x , f ,  x  , f0 ,  x + c * T , f0 , 'r')
# Out:
# [<matplotlib.lines.Line2D at 0x7f07fe793380>,
#  <matplotlib.lines.Line2D at 0x7f07fe7934d0>,
#  <matplotlib.lines.Line2D at 0x7f07fe793620>]

# %% [markdown]
# ### Reflexiones

# %% [markdown]
# * ¿Qué hemos hecho en los bordes? (condiciones de contorno)
# * ¿Por qué los algoritmos difieren tantísimo?
# * ¿Cuántos parámetros hay realmente? (Pista: 1)
